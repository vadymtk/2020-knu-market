# %%
# %matplotlib inline
import datetime as datetime
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
import matplotlib.pyplot as plt
from Elasticity import elasticity_ols_models
from Elasticity import elasticity_ols
from Visualization import plot_dynamics, give_data

# %%
data = give_data()
data_traditional = data[data['Source'] == 'Traditional Sales']
elasticity_ols_models(data_traditional, ['GA-B429SECZ'], give_info=True)
# Out:
# D:\1\lib\site-packages\scipy\stats\stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Quantity   R-squared:                       0.137
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     1.588
# Date:                Wed, 05 Feb 2020   Prob (F-statistic):              0.236
# Time:                        18:12:18   Log-Likelihood:                -76.894
# No. Observations:                  12   AIC:                             157.8
# Df Residuals:                      10   BIC:                             158.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -890.7628   1162.535     -0.766      0.461   -3481.053    1699.527
# PriceUSD       2.8044      2.225      1.260      0.236      -2.154       7.762
# ==============================================================================
# Omnibus:                        0.551   Durbin-Watson:                   1.145
# Prob(Omnibus):                  0.759   Jarque-Bera (JB):                0.583
# Skew:                           0.295   Prob(JB):                        0.747
# Kurtosis:                       2.096   Cond. No.                     1.31e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#          Model  Elasticity
# 0  GA-B429SECZ    2.804369

# %%
res = elasticity_ols_models(data_traditional, data_traditional['Model'].unique())

# %%
res1 = res[res['Elasticity']>0.5]
res1
# Out:
#              Model  Elasticity
# 2      GA-B429SECZ    2.804369
# 11         BCD-138    3.772702
# 13   GA-B 389 SMQZ    0.825359
# 16     GA-B429SMQZ    1.883214
# 17     XM-6025 100    2.635396
# ..             ...         ...
# 904         SD50WA    0.649614
# 920    XM 4624-101    0.584320
# 936       CW 286 W    2.903060
# 948    NRK6202GHW4    0.613768
# 969    CNA295K20XP    0.976261
#
# [73 rows x 2 columns]
