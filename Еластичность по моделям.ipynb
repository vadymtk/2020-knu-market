# %%
# %matplotlib inline
import datetime as datetime
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
import matplotlib.pyplot as plt
from Elasticity import elasticity_ols_models
from Elasticity import elasticity_ols
from Visualization import plot_dynamics, give_data

# %%
data = give_data()
data_traditional = data[data['Source'] == 'Traditional Sales']
elasticity_ols_models(data_traditional, ['RB37J5000EF/UA'], give_info=True)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
#                             OLS Regression Results
# ...
# Dep. Variable:               Quantity   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.083
# Method:                 Least Squares   F-statistic:                    0.1528
# Date:                Wed, 05 Feb 2020   Prob (F-statistic):              0.704
# Time:                        19:40:59   Log-Likelihood:                -73.422
# No. Observations:                  12   AIC:                             150.8
# Df Residuals:                      10   BIC:                             151.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
res = elasticity_ols_models(data_traditional, data_traditional['Model'].unique())

# %%
res1 = res[res['Elasticity']>0.4]
res1
# Out:
#               Model  Elasticity
# 2       GA-B429SECZ    2.804369
# 4    RB37J5000EF/UA    0.455472
# 11          BCD-138    3.772702
# 13    GA-B 389 SMQZ    0.825359
# 15      GA-B429SMQZ    1.883214
# ..              ...         ...
# 586  SD100WA 11N TM    1.106866
# 599    RF300-1801AA    0.508458
# 613  RB33J3201SA/UA    0.832952
# 645       HRF-230 X    0.688895
# 662          MR-145    0.747131
#
# [77 rows x 2 columns]
